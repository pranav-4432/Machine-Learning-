# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Updated_Students_Performance_Dataset.csv")

# %%
data.head()
# Out:
#   Student_ID First_Name Last_Name              Email  Gender  Age  \
# 0      S1000       Omar  Williams  student0@univ.edu  Female   22
# 1      S1001      Maria     Brown  student1@univ.edu    Male   18
# 2      S1002      Ahmed     Jones  student2@univ.edu    Male   24
# 3      S1003       Omar  Williams  student3@univ.edu    Male   24
# 4      S1004       John     Smith  student4@univ.edu  Female   23
#
#     Department  Attendance (%)  Midterm_Score  Final_Score  ...  Quizzes_Avg  \
# 0  Mathematics           97.36          40.61        59.61  ...        53.17
# 1     Business           97.71          57.27        74.00  ...        98.23
# 2  Engineering           99.52          41.84        63.85  ...        50.00
# 3  Engineering           90.38          45.65        44.44  ...        66.27
# 4           CS           59.41          53.13        61.77  ...        83.98
#
#    Participation_Score  Study_Hours_per_Week  Extracurricular_Activities  \
# 0                 82.4                  10.3                         Yes
# 1                 75.1                  27.1                          No
# 2                 88.3                  12.4                         Yes
# 3                 64.2                  25.5                          No
# 4                 91.0                  13.3                         Yes
#
#   Internet_Access Parent_Education Family_Income Stress_Level  \
# 0              No         Master's        Medium            1
# 1              No      High School           Low            4
# 2              No      High School           Low            9
# 3             Yes      High School           Low            8
# 4              No         Master's        Medium            6
#
#    Final_Grade_Score  Grade
# 0            59.8255      F
# 1            73.1895      C
# 2            64.7855      D
# 3            53.5505      F
# 4            70.1970      C
#
# [5 rows x 21 columns]

# %%
x=data[["Study_Hours_per_Week"]]
y=data["Final_Score"]

# %%
model=LinearRegression()
model.fit(x,y)
predicted_score= model.predict(x)

# %%
mse=mean_squared_error(y,predicted_score)
mae=mean_absolute_error(y,predicted_score)
rmse=np.sqrt(mse)
r2=r2_score(y,predicted_score)

# %%
print("Mean squared error",round(mse,2))
print("Mean absolute error",round(mae,2))
print("Root mean squared error",round(rmse,2))
print("R*2 score (Model Accuracy)",round(r2,2))
# Out:
# Mean squared error 325.03
# Mean absolute error 15.95
# Root mean squared error 18.03
# R*2 score (Model Accuracy) 0.0

# %%
plt.figure(figsize=(10,6))
plt.hist(data["Final_Score"],bins=30,color="skyblue",edgecolor="black" )
plt.title("Distribution of final exam score")
plt.xlabel("Final exam score ")
plt.ylabel("Number of students")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(x,y,color="blue",label="Actual scores" )
plt.plot(x,predicted_score ,color="red",label="Predicted scores(Regression line)")
plt.title("Model Prediction vs actual score")
plt.xlabel("Final exam score ")
plt.ylabel("Number of students")
plt.grid(True)
plt.show()

# %%
predicted_new_score=model.predict([[9]])
print(predicted_new_score)
# Out:
# [69.34963281]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
